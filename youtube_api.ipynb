# %%
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from oauth2client.tools import argparser
import logging
logging.getLogger('googleapicliet.discovery_cache').setLevel(logging.ERROR)
logging.getLogger('googleapiclient.discovery').setLevel(logging.CRITICAL)

# %%
DEVELOPER_KEY = 'AIzaSyDJ0PdUK4sVK89ikALt2uv-k_1Gde-5l4Q'
YOUTUBE_API_SERVICE_NAME = 'youtube'
YOUTUBE_API_VERSION = 'v3'

# %%
import pandas as pd
import numpy as np

# %%
golf_df = pd.DataFrame(columns=['Title','Date','VideoId', 'PlaylistId'])

# %%
pageToken = 'CDIQAA',

# %%
def youtube_search():
    youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION, 
                    developerKey=DEVELOPER_KEY, cache_discovery=False)
    
    MAX_COUNT=50
    nextPageToken = None
    search_by = '골프'
    
    for i in range(1):
        req = youtube.search().list(q=search_by, part='snippet', type='vieo',
                                   maxResults=MAX_COUNT,
                                   pageToken = nextPageToken)
        res = req.execute()
        
        nextPageToken = res['nextPageToken']
        items = res['items']
        if res['nextPageToken'] == None:
            break
            for each_item in items:
                print(each_item)

# %%
golf_df
# Out:
#                                                 Title  \
# 0                골프존 카운티 안성Q 보기 없이 무구기 플레이 100% 혼자스크린
# 2                                 스크린골프-골프존안성Q 18홀 +3
# 3                                   골프존카운티 안성Q 친선 라운딩
# 4   마스터골프 골프존카운티안성Q cc후반9홀 스크린혼자놀기 golf simulator ...
# 5   마스터골프 골프존 카운티 안성Q 혼자스크린치기 golf swimg  golf sim...
# 6        골프존카운티 안성Q 최종순위는!? 또 반전이 나왔습니다. [구독자 이벤트 발표]
# 7       골프존카운티 안성Q 권팀장님과 골프대결! 실력과 멘탈이~ [구독자 이벤트 진행!]
# 8          골프 클럽 2019 Q스쿨 통과 GOLF CLUB 2019 FEATURING
# 10                        실시간 골프연습및 Q and A | 마이크 테스트
# 11                                 여자들의 #내기골프 안성Q 라운드
# 12                                 골프존문화재단배 마지막연습 안성Q
# 13                [스크린골프 안성Q 후반전] 어프로치 달인, 샷감이 돌아 왔다.
# 14  골프장 맛집! 안성에서 골프치고 뭐 먹지? 안성 Q 주변 맛집을 소개합니다!_골프존카운티
# 15                           참 좋은 골프장 안성Q를 즐기는 5가지 방법
# 16  [Q?] 아이언 샷 정확도를 올리는 방법 (with. 고덕호 프로)｜ 민학수의 Al...
# 17    Asian Tour Q School Interview | Golf with Aimee
# ...

# %%
def youtube_search2():
    youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION, 
                    developerKey=DEVELOPER_KEY, cache_discovery=False)
    
    search_response = youtube.search().list(
        q='골프,golf,골프레슨',
        order = 'date',
        part = 'snippet',
        pageToken = 'CDIQAA',
        maxResults=50).execute()
    
    num = 50
    
    for search_result in search_response.get('items', []):
        if search_result['id']['kind'] == 'youtube#video':
            
            golf_df.loc[num, 'Title'] = search_result['snippet']['title']
            golf_df.loc[num, 'Date'] = search_result['snippet']['publishedAt']
            golf_df.loc[num, 'VideoId'] = search_result['id']['videoId']
           
            num += 1
